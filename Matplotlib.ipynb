# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore') # ignores the warnings

# %%
#line, scatter, bar, histogram, pie chart, box plot, violin plot

# %%
x = np.random.rand(50)

# %%
x
# Out:
# array([0.54705472, 0.69272707, 0.54879068, 0.25966686, 0.81842356,
#        0.2605511 , 0.21549794, 0.93683514, 0.12498071, 0.34299832,
#        0.35549502, 0.20672027, 0.43069217, 0.03000655, 0.05780758,
#        0.09788144, 0.51240432, 0.31840881, 0.49263074, 0.05781767,
#        0.34751751, 0.00714118, 0.62507649, 0.55318708, 0.0288747 ,
#        0.69207883, 0.9543023 , 0.5027884 , 0.2728426 , 0.9703931 ,
#        0.15952137, 0.32201718, 0.22707383, 0.0594669 , 0.4793325 ,
#        0.51337176, 0.04366609, 0.30715466, 0.37444236, 0.08221604,
#        0.63082399, 0.04116124, 0.74855912, 0.64279614, 0.58975164,
#        0.16226283, 0.77313517, 0.98342294, 0.74007823, 0.23122163])

# %%
df = pd.DataFrame(np.random.rand(1000), columns= ['Data'], index = pd.date_range('2025-04-10', periods=1000) )

# %%
df
# Out:
#                 Data
# 2025-04-10  0.234954
# 2025-04-11  0.020144
# 2025-04-12  0.341200
# 2025-04-13  0.175833
# 2025-04-14  0.407802
# ...              ...
# 2027-12-31  0.450868
# 2028-01-01  0.574555
# 2028-01-02  0.544312
# 2028-01-03  0.265480
# 2028-01-04  0.673102
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20,8)) #plotted the line chart using pandas only
# Out:
# <Axes: >

# %%
x = np.random.randn(50)
y = np.random.randn(50)

# %%
#scatter plot >> A scatter plot is a type of data visualization that displays values for two variables as points on a Cartesian plane. Each point represents the value of one variable corresponding to the value of the other variable
plt.scatter(x,y, color='r')

# %%
#line plot
#whenever you want to depict the relation between two variables in the form of trend
#mostly in x axis the date - time column is there
x = [1, 2, 3, 4, 5] #assume x is no of day
y = [5, 2, 7, 8, 1] #y is price of stock

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y, color='g')
plt.title("Line Chart")
plt.xlabel("No of Days")
plt.ylabel("Proce of the stock")
plt.grid()
plt.show()

# %%
plt.plot(x,y, color='g', marker = 'o', linestyle = '--')
plt.title("Line Chart")
plt.xlabel("No of Days")
plt.ylabel("Proce of the stock")
plt.grid()
plt.show()

# %%
plt.plot(x,y, color='g', marker = 'o', linestyle = '--', linewidth = 4, markersize = 10)
plt.title("Line Chart")
plt.xlabel("No of Days")
plt.ylabel("Proce of the stock")
plt.grid()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [5, 1, 7, 8, 2]
y2 = [7, 8, 3, 5, 1]
plt.plot(x,y1,color='r', label = 'line 1', marker = 'o', linestyle = '--')
plt.plot(x, y2, color = 'b', label = 'line 2', marker = 'o', linestyle = '--')
plt.grid()
plt.legend()
plt.title("Stakced Line Chart")
plt.xlabel("No of days")
plt.ylabel("Price of stock")
plt.show()

# %%
x = np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x, np.sin(x))

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.figure() #initialising a page to make plot
plt.subplot(1,2,1)
plt.plot(x, np.sin(x))
plt.subplot(1,2,2)
plt.plot(x, np.cos(x))
plt.show()

# %%
plt.figure() #initialising a page to make plot
plt.subplot(2,1,1)
plt.plot(x, np.sin(x))
plt.subplot(2,1,2)
plt.plot(x, np.cos(x))
plt.show()

# %%
plt.figure() #initialising a page to make plot
plt.subplot(2,2,1)
plt.plot(x, np.sin(x))
plt.subplot(2,2,2)
plt.plot(x, np.cos(x))
plt.subplot(2,2,3)
plt.plot(x, np.tan(x))
plt.subplot(2,2,4)
plt.plot(x, np.cos(x+1))
plt.show()

# %%
plt.plot(x, np.sin(x), color = 'magenta')
plt.xlim(1,15)
plt.ylim(-1.5, 1.5)
plt.show()

# %%
plt.plot(x, np.sin(x), color = 'magenta')
plt.xlim(1,15)
plt.ylim(-1.5, 1.5)
plt.axis('equal')
plt.grid()
plt.title("basic syntax")
plt.xlabel("x label")
plt.ylabel("y label")
plt.show()

# %%
#histogram>> continuous numerical data
x = np.random.randn(1000)

# %%
plt.hist(x)
plt.show() #be default it shows 10 bins we can explicitly specify the number of bins here

# %%
plt.hist(x, bins = 20, color = 'lightgreen')
plt.show()

# %%
data1 = np.random.randn(50)
data2 = np.random.randn(50)
plt.hist([data1, data2], bins = 10, color = ['r','b'], label = ['Data1', 'Data2'])
plt.xlabel("Values")
plt.ylabel('frequency')
plt.legend()
plt.title("stacked histogram")
# Out:
# Text(0.5, 1.0, 'stacked histogram')

# %%
#scatterplot >> to understand the relationship between two features
plt.scatter(data1, data2, marker = 'X')
plt.show()

# %%
#bar plot >> To see the districution of categorical variables
x = ["a", "b", "c","d"] #name of students
y = [4, 6, 1, 10] #no of days present in the class

plt.bar(x,y, color = 'magenta')
plt.show()

# %%
plt.barh(x,y, color = 'magenta')
plt.show()

# %%
#pie char >> To understand the percent distribution of data
langs = ["C", "Python", "Java"]
students = [20, 100, 40]
plt.pie(students, labels = langs, autopct = "%1.1f%%")
plt.show()

# %%
explode = [0,0.1, 0.1]
plt.pie(students, labels = langs, autopct = "%1.1f%%",explode = explode,shadow = True)
plt.show()

# %%
# 3-d plot
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)
fig = plt.figure()
ax = plt.axes(projection = '3d')
ax.scatter(x,y,z)
